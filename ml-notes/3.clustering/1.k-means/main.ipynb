# %% [markdown]
# <h2>K-Means Clustering</h2>
#
# ***K-Means Clustering*** is a popular unsupervised machine learning algorithm used for partitioning a dataset into a set of distinct, non-overlapping groups (clusters). <br>
#
# It aims to group similar data points together while ensuring that the data points within the same cluster are more similar to each other than to those in other clusters.
#
# <h4>Key Concepts</h4>
#
# 1. **Clusters**: Groups of similar data points;
# 2. **Centroids**: Centers of the clusters;
#
# <h4>Steps of the K-Means Algorithm</h4>
#
# 1. ***Initialization***: Select N initial centroids randomly;
# 2. ***Assignment***: Assign each data point to the nearest centroid;
# 3. ***Update***: Calculate new centroids as the mean of the assigned points;
# 4. ***Repeat***: Iterate the assignment and update steps until centroids stabilize;
#
# <h4>Practical Tips</h4>
#
# - **Choosing N**: Use methods like Elbow Method or Silhouette Analysis;
# - **Preprocessing**: Normalize data for better performance;

# %% [markdown]
# <h4>Importing libraries</h4>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# <h4>Loading the iris dataset</h4>

# %%
from sklearn.datasets import make_blobs    
np.random.seed(42)
X, y = make_blobs(
    centers=4, n_samples=600, n_features=2, shuffle=True, random_state=40
)
print("Shape:", X.shape)

n_clusters = len(np.unique(y))
print("Number of clusters:", n_clusters)
# Out:
# Shape: (600, 2)
# Number of clusters: 4

# %% [markdown]
# <h4>Visualizing the dataset</h4>

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1], c = "red")
plt.scatter(X[y == 1, 0], X[y == 1, 1], c = "green")
plt.scatter(X[y == 2, 0], X[y == 2, 1], c = "blue")
plt.scatter(X[y == 3, 0], X[y == 3, 1], c = "purple")
plt.title("The original dataset")
plt.show()

# %% [markdown]
# <h4>Training the K-Means</h4>

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=n_clusters)
model.fit(X)
y_pred = model.predict(X)

# %% [markdown]
# <h4>Visualizing the predictions</h4>

# %%
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], c = "red")
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], c = "green")
plt.scatter(X[y_pred == 2, 0], X[y_pred == 2, 1], c = "blue")
plt.scatter(X[y_pred == 3, 0], X[y_pred == 3, 1], c = "purple")
plt.title("The predictions")
plt.show()
